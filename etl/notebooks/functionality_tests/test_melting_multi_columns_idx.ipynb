# %%
import yfinance as yf
ticker_list = ["TD.TO", "RY.TO", "BMO.TO"]

# %%
# Import price data using
tickers = yf.Tickers(ticker_list)

# %%
df = tickers.history(start='2025-11-01', end='2025-11-30')
# Out:
# [*********************100%***********************]  3 of 3 completed

# %%
df.stack(level=1, future_stack=True).reset_index() # as expected
# Out:
# Price       Date  Ticker       Close  Dividends        High         Low  \
# 0     2025-11-03  BMO.TO  175.490005        0.0  175.649994  173.080002
# 1     2025-11-03   RY.TO  207.220001        0.0  207.639999  205.000000
# 2     2025-11-03   TD.TO  115.180000        0.0  116.489998  114.959999
# 3     2025-11-04  BMO.TO  172.720001        0.0  175.470001  172.110001
# 4     2025-11-04   RY.TO  205.399994        0.0  206.979996  204.690002
# 5     2025-11-04   TD.TO  113.559998        0.0  115.129997  113.440002
# 6     2025-11-05  BMO.TO  173.210007        0.0  174.179993  172.300003
# 7     2025-11-05   RY.TO  205.639999        0.0  205.880005  204.479996
# 8     2025-11-05   TD.TO  113.849998        0.0  114.239998  112.980003
# 9     2025-11-06  BMO.TO  173.669998        0.0  174.089996  172.479996
# 10    2025-11-06   RY.TO  205.250000        0.0  206.169998  204.369995
# 11    2025-11-06   TD.TO  113.540001        0.0  114.379997  112.290001
# ...
