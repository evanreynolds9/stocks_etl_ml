# %%
# Import packages
import pandas as pd
import edgar
from edgar.xbrl import XBRLS
import os
from dotenv import load_dotenv
from etl.utils.utils import extract_query

# Load .env
load_dotenv()
email = os.getenv("EMAIL")
db_username = os.getenv("DB_USERNAME")
db_password = os.getenv("DB_PASSWORD")
db_host = os.getenv("DB_HOST")
db_port = os.getenv("DB_PORT")

# Create db connection string
db_conn_str = f"mysql+pymysql://{db_username}:{db_password}@{db_host}:{db_port}/stocks_etl_ml_db"

# %%
# Load sp_tickers from db
ticker_query = """
SELECT *
FROM sp_constituents
"""

# Load into df
df_tickers = extract_query(db_conn_str, ticker_query)
# Out:
# Connection Successful!
# SQL script executed successfully!

# %%
df_tickers
# Out:
#     Actual_Date  Load_Date Tickers
# 0    2018-04-24 2018-05-01       A
# 1    2018-04-24 2018-05-01     AAL
# 2    2018-04-24 2018-05-01     AAP
# 3    2018-04-24 2018-05-01    AAPL
# 4    2018-04-24 2018-05-01    ABBV
# ..          ...        ...     ...
# 501  2018-04-24 2018-05-01     XYL
# 502  2018-04-24 2018-05-01     YUM
# 503  2018-04-24 2018-05-01     ZBH
# 504  2018-04-24 2018-05-01    ZION
# 505  2018-04-24 2018-05-01     ZTS
#
# [506 rows x 3 columns]

# %%
# Set identity for SEC requirement
edgar.set_identity(email)

# %%
# Get data from a random company
comp = df_tickers.loc[250]

ticker = comp['Tickers']
end_date = comp['Load_Date']

# Set date range
start_date = (end_date - pd.DateOffset(years=1)) + pd.Timedelta(days=1)

date_range = f"{start_date.strftime('%Y-%m-%d')}:{end_date.strftime('%Y-%m-%d')}"
print(date_range)
# Out:
# 2017-05-02:2018-05-01

# %%
# Create company with edgar
company = edgar.Company(ticker)

# %%
# Get 10-k in date range for the company
filings = company.get_filings(form = "10-K", filing_date = date_range, is_xbrl = True)

# %%
# Parse xbrl
filing = filings[0]

# Get a few key dates
filing_date = filing.filing_date
filing_period = filing.period_of_report

# %%
# Get financials
# Parse xbrl
xbrl = filing.xbrl()

# Extract standardized financials
financials = edgar.Financials(xbrl)

balance_sheet = financials.balance_sheet()
income_statement = financials.income_statement()
cash_flow_statement = financials.cashflow_statement()

# %%
balance_sheet.to_dataframe()
# Out:
#                                               concept  \
# 0                              us-gaap_AssetsAbstract
# 1                       us-gaap_AssetsCurrentAbstract
# 2       us-gaap_CashAndCashEquivalentsAtCarryingValue
# 3                       us-gaap_ReceivablesNetCurrent
# 4                       us-gaap_PrepaidExpenseCurrent
# 5                       us-gaap_IncomeTaxesReceivable
# 6                        us-gaap_ShortTermInvestments
# 7                          us-gaap_OtherAssetsCurrent
# 8                               us-gaap_AssetsCurrent
# 9                us-gaap_PropertyPlantAndEquipmentNet
# 10                        us-gaap_LongTermInvestments
# 11  us-gaap_InvestmentsInAndAdvancesToAffiliatesAm...
# 12                                   us-gaap_Goodwill
# 13       us-gaap_IntangibleAssetsNetExcludingGoodwill
# 14             us-gaap_DeferredTaxAssetsNetNoncurrent
# 15                                us-gaap_OtherAssets
# 16                                     us-gaap_Assets
# 17   us-gaap_LiabilitiesAndStockholdersEquityAbstract
# 18                 us-gaap_LiabilitiesCurrentAbstract
# 19                     us-gaap_AccountsPayableCurrent
# 20                  us-gaap_AccruedLiabilitiesCurrent
# 21                     us-gaap_DeferredRevenueCurrent
# 22                  us-gaap_AccruedIncomeTaxesCurrent
# 23                        us-gaap_LongTermDebtCurrent
# 24                    us-gaap_OtherLiabilitiesCurrent
# 25                         us-gaap_LiabilitiesCurrent
# 26                     us-gaap_LongTermDebtNoncurrent
# 27      us-gaap_DeferredTaxLiabilitiesGrossNoncurrent
# 28                 us-gaap_OtherLiabilitiesNoncurrent
# 29                                us-gaap_Liabilities
# 30                us-gaap_CommitmentsAndContingencies
# 31  us-gaap_StockholdersEquityIncludingPortionAttr...
# 32  us-gaap_CommonStocksIncludingAdditionalPaidInC...
# 33         us-gaap_RetainedEarningsAccumulatedDeficit
# 34                         us-gaap_TreasuryStockValue
# 35  us-gaap_AccumulatedOtherComprehensiveIncomeLos...
# 36                         us-gaap_StockholdersEquity
# 37                           us-gaap_MinorityInterest
# 38  us-gaap_StockholdersEquityIncludingPortionAttr...
# 39           us-gaap_LiabilitiesAndStockholdersEquity
#
#                                                label     2017-12-31  \
# 0                                             ASSETS
# 1                                    Current assets:
# 2                          Cash and Cash Equivalents    959000000.0
# 3                                Accounts Receivable   1993000000.0
# 4                                   Prepaid Expenses    146000000.0
# 5                            Income taxes receivable     47000000.0
# 6   Investments in debt, equity and other securities     46000000.0
# 7                               Other Current Assets    259000000.0
# 8                               Total Current Assets   3450000000.0
# 9                      Property, Plant and Equipment    440000000.0
# 10                             Long-Term Investments      8000000.0
# 11          Investments in unconsolidated affiliates     70000000.0
# 12                                          Goodwill  11850000000.0
# 13                                 Intangible Assets   6591000000.0
# 14                             Deferred income taxes     98000000.0
# 15                                      Other Assets    235000000.0
# 16                                      Total Assets  22742000000.0
# 17              LIABILITIES AND STOCKHOLDERS’ EQUITY
# 18                              Current liabilities:
# 19                                  Accounts Payable    322000000.0
# 20                               Accrued Liabilities   1664000000.0
# 21                                  Deferred Revenue    733000000.0
# 22                              Income taxes payable     72000000.0
# 23                                   Short Term Debt    103000000.0
# 24                         Other Current Liabilities     10000000.0
# 25                         Total Current Liabilities   2904000000.0
# 26                                    Long Term Debt  10122000000.0
# 27                             Deferred income taxes    918000000.0
# 28                     Other Non Current Liabilities    440000000.0
# 29                                 Total Liabilities  14384000000.0
# 30            Commitments and contingencies (Note 1)
# 31                             Stockholders’ equity:
# 32                                      Common Stock  10782000000.0
# 33                                 Retained Earnings    655000000.0
# 34                       Treasury Stock Common Value  -3374000000.0
# 35       Accumulated Other Comprehensive Income/Loss     46000000.0
# 36                        Total Stockholders' Equity   8109000000.0
# 37                                 Minority Interest    249000000.0
# 38                        Total Stockholders' Equity   8358000000.0
# 39        Total Liabilities and Stockholders' Equity  22742000000.0
#
#        2016-12-31  level  abstract  dimension
# 0                      1     False      False
# 1                      2     False      False
# 2    1198000000.0      3     False      False
# 3    1707000000.0      3     False      False
# 4     123000000.0      3     False      False
# 5      34000000.0      3     False      False
# 6      40000000.0      3     False      False
# 7     235000000.0      3     False      False
# 8    3337000000.0      3     False      False
# 9     406000000.0      2     False      False
# 10     13000000.0      2     False      False
# 11     69000000.0      2     False      False
# 12  10727000000.0      2     False      False
# 13   6390000000.0      2     False      False
# 14     89000000.0      2     False      False
# 15    177000000.0      2     False      False
# 16  21208000000.0      2     False      False
# 17                     1     False      False
# 18                     2     False      False
# 19    250000000.0      3     False      False
# 20   1493000000.0      3     False      False
# 21    774000000.0      3     False      False
# 22     76000000.0      3     False      False
# 23     92000000.0      3     False      False
# 24     20000000.0      3     False      False
# 25   2705000000.0      3     False      False
# 26   7108000000.0      2     False      False
# 27   2133000000.0      2     False      False
# 28    402000000.0      2     False      False
# 29  12348000000.0      2     False      False
# 30                     2     False      False
# 31                     2     False      False
# 32  10602000000.0      3     False      False
# 33   -399000000.0      3     False      False
# 34  -1000000000.0      3     False      False
# 35   -570000000.0      3     False      False
# 36   8633000000.0      3     False      False
# 37    227000000.0      3     False      False
# 38   8860000000.0      3     False      False
# 39  21208000000.0      2     False      False

# %%
income_statement.to_dataframe()
# Out:
#                                               concept  \
# 0                     us-gaap_SalesRevenueServicesNet
# 1                        us-gaap_ReimbursementRevenue
# 2                                    us-gaap_Revenues
# 3   us-gaap_CostOfServicesExcludingDepreciationDep...
# 4                   us-gaap_CostOfReimbursableExpense
# 5      us-gaap_SellingGeneralAndAdministrativeExpense
# 6        us-gaap_DepreciationDepletionAndAmortization
# 7                        us-gaap_RestructuringCharges
# 8   us-gaap_BusinessCombinationIntegrationRelatedC...
# 9                      us-gaap_AssetImpairmentCharges
# 10                        us-gaap_OperatingIncomeLoss
# 11                   us-gaap_InvestmentIncomeInterest
# 12                            us-gaap_InterestExpense
# 13          us-gaap_GainsLossesOnExtinguishmentOfDebt
# 14             us-gaap_OtherNonoperatingIncomeExpense
# 15  us-gaap_IncomeLossFromContinuingOperationsBefo...
# 16                    us-gaap_IncomeTaxExpenseBenefit
# 17  iqv_IncomeLossFromContinuingOperationsAfterInc...
# 18      us-gaap_IncomeLossFromEquityMethodInvestments
# 19                                 us-gaap_ProfitLoss
# 20  us-gaap_NetIncomeLossAttributableToNoncontroll...
# 21                              us-gaap_NetIncomeLoss
# 22                   us-gaap_EarningsPerShareAbstract
# 23                      us-gaap_EarningsPerShareBasic
# 24                    us-gaap_EarningsPerShareDiluted
# 25  us-gaap_WeightedAverageNumberOfSharesOutstandi...
# 26  us-gaap_WeightedAverageNumberOfSharesOutstandi...
# 27  us-gaap_WeightedAverageNumberOfDilutedSharesOu...
#
#                                                 label    2017-12-31  \
# 0                                            Revenues  8060000000.0
# 1                                 Reimbursed expenses  1679000000.0
# 2                                             Revenue  9739000000.0
# 3   Costs of revenue, exclusive of depreciation an... -4622000000.0
# 4               Costs of revenue, reimbursed expenses -1679000000.0
# 5         Selling, General and Administrative Expense -1605000000.0
# 6                       Depreciation and amortization -1011000000.0
# 7                                 Restructuring costs   -63000000.0
# 8                                Merger related costs
# 9                                  Impairment charges   -40000000.0
# 10                                   Operating Income   719000000.0
# 11                                    Interest income     7000000.0
# 12                                   Interest Expense  -346000000.0
# 13                     Loss on extinguishment of debt   -19000000.0
# 14                        Other expense (income), net   -30000000.0
# 15  Income before income taxes and equity in earni...   331000000.0
# 16                                 Income Tax Expense   987000000.0
# 17  Income before equity in earnings (losses) of u...  1318000000.0
# 18  Equity in earnings (losses) of unconsolidated ...    10000000.0
# 19                                     Profit or Loss  1328000000.0
# 20  Net Income Attributable to Noncontrolling Inte...   -19000000.0
# 21                                         Net Income  1309000000.0
# 22                                 Earnings Per Share
# 23                         Earnings Per Share (Basic)          6.01
# 24                       Earnings Per Share (Diluted)          5.88
# 25                                 Shares Outstanding
# 26                         Shares Outstanding (Basic)   217800000.0
# 27                       Shares Outstanding (Diluted)   222600000.0
#
#       2016-12-31    2015-12-31  level  abstract  dimension
# 0   5364000000.0  4326000000.0      1     False      False
# 1   1514000000.0  1411000000.0      1     False      False
# 2   6878000000.0  5737000000.0      1     False      False
# 3  -3236000000.0 -2705000000.0      1     False      False
# 4  -1514000000.0 -1411000000.0      1     False      False
# 5  -1011000000.0  -815000000.0      1     False      False
# 6   -289000000.0  -128000000.0      1     False      False
# 7    -71000000.0   -30000000.0      1     False      False
# 8    -87000000.0                    1     False      False
# 9    -28000000.0    -2000000.0      1     False      False
# 10   642000000.0   646000000.0      1     False      False
# 11     4000000.0     4000000.0      1     False      False
# 12  -144000000.0  -101000000.0      1     False      False
# 13   -31000000.0    -8000000.0      1     False      False
# 14     8000000.0    -2000000.0      1     False      False
# 15   479000000.0   539000000.0      1     False      False
# 16  -345000000.0  -159000000.0      1     False      False
# 17   134000000.0   380000000.0      1     False      False
# 18    -4000000.0     8000000.0      1     False      False
# 19   130000000.0   388000000.0      1     False      False
# 20   -15000000.0    -1000000.0      1     False      False
# 21   115000000.0   387000000.0      1     False      False
# 22                                  1     False      False
# 23          0.77          3.15      2     False      False
# 24          0.76          3.08      2     False      False
# 25                                  1     False      False
# 26   149100000.0   123000000.0      2     False      False
# 27   152000000.0   125600000.0      2     False      False

# %%
cash_flow_statement.to_dataframe()
# Out:
#                                               concept  \
# 0   us-gaap_NetCashProvidedByUsedInOperatingActivi...
# 1                                  us-gaap_ProfitLoss
# 2   us-gaap_AdjustmentsNoncashItemsToReconcileNetI...
# 3        us-gaap_DepreciationDepletionAndAmortization
# 4    us-gaap_AmortizationOfFinancingCostsAndDiscounts
# 5   iqv_AmortizationOfAccumulatedOtherComprehensiv...
# 6                      us-gaap_ShareBasedCompensation
# 7                      us-gaap_AssetImpairmentCharges
# 8      us-gaap_GainLossOnSaleOfPropertyPlantEquipment
# 9   us-gaap_IncomeLossFromEquityMethodInvestmentsN...
# 10                us-gaap_GainLossOnSaleOfInvestments
# 11            us-gaap_DeferredIncomeTaxExpenseBenefit
# 12  us-gaap_ExcessTaxBenefitFromShareBasedCompensa...
# 13  us-gaap_IncreaseDecreaseInOperatingCapitalAbst...
# 14              us-gaap_IncreaseDecreaseInReceivables
# 15  us-gaap_IncreaseDecreaseInPrepaidDeferredExpen...
# 16  us-gaap_IncreaseDecreaseInAccountsPayableAndAc...
# 17          us-gaap_IncreaseDecreaseInDeferredRevenue
# 18  us-gaap_IncreaseDecreaseInAccruedLiabilitiesAn...
# 19  us-gaap_NetCashProvidedByUsedInOperatingActivi...
# 20  us-gaap_NetCashProvidedByUsedInInvestingActivi...
# 21          us-gaap_PaymentsToAcquireProductiveAssets
# 22  us-gaap_PaymentsToAcquireBusinessesNetOfCashAc...
# 23  us-gaap_ProceedsFromDivestitureOfBusinessesNet...
# 24         us-gaap_PaymentsForProceedsFromInvestments
# 25          us-gaap_ProceedsFromLifeInsurancePolicies
# 26  us-gaap_ProceedsFromSaleOfAvailableForSaleSecu...
# 27  iqv_PaymentForProceedsFromAcquireInterestInSub...
# 28        us-gaap_PaymentsForHedgeInvestingActivities
# 29  us-gaap_PaymentsForProceedsFromOtherInvestingA...
# 30  us-gaap_NetCashProvidedByUsedInInvestingActivi...
# 31  us-gaap_NetCashProvidedByUsedInFinancingActivi...
# 32                 us-gaap_ProceedsFromIssuanceOfDebt
# 33                us-gaap_PaymentsOfDebtIssuanceCosts
# 34                           us-gaap_RepaymentsOfDebt
# 35                  us-gaap_ProceedsFromLinesOfCredit
# 36                  us-gaap_RepaymentsOfLinesOfCredit
# 37  us-gaap_RepaymentsOfLongTermCapitalLeaseObliga...
# 38  us-gaap_PaymentsOfMergerRelatedCostsFinancingA...
# 39  us-gaap_ProceedsFromIssuanceOfSharesUnderIncen...
# 40         us-gaap_PaymentsForRepurchaseOfCommonStock
# 41  us-gaap_ExcessTaxBenefitFromShareBasedCompensa...
# 42  us-gaap_NetCashProvidedByUsedInFinancingActivi...
# 43  us-gaap_EffectOfExchangeRateOnCashAndCashEquiv...
# 44  us-gaap_CashAndCashEquivalentsPeriodIncreaseDe...
# 45      us-gaap_CashAndCashEquivalentsAtCarryingValue
# 46      us-gaap_CashAndCashEquivalentsAtCarryingValue
#
#                                                 label    2017-12-31  \
# 0                               Operating activities:
# 1                                      Profit or Loss  1328000000.0
# 2   Adjustments to reconcile net income to cash pr...
# 3                       Depreciation and amortization -1011000000.0
# 4    Amortization of debt issuance costs and discount     9000000.0
# 5   Amortization of accumulated other comprehensiv...     3000000.0
# 6                            Stock-based compensation   106000000.0
# 7                                  Impairment charges   -40000000.0
# 8    Gain on disposals of property and equipment, net    -1000000.0
# 9      (Earnings) loss from unconsolidated affiliates   -10000000.0
# 10                    (Gain) loss on investments, net    -8000000.0
# 11  (Benefit from) provision for deferred income t... -1216000000.0
# 12  Excess income tax benefits from stock-based aw...
# 13       Changes in operating assets and liabilities:
# 14          Accounts receivable and unbilled services  -142000000.0
# 15                  Prepaid expenses and other assets   -54000000.0
# 16              Accounts payable and accrued expenses    90000000.0
# 17                                    Unearned income  -104000000.0
# 18         Income taxes payable and other liabilities   -82000000.0
# 19                 Net Cash from Operating Activities   970000000.0
# 20                              Investing activities:
# 21    Acquisition of property, equipment and software  -369000000.0
# 22                     Payments to Acquire Businesses  -854000000.0
# 23      Disposition of business, net of cash disposed    12000000.0
# 24       Sales (purchases) of trading securities, net     2000000.0
# 25  Proceeds from corporate owned life insurance p...
# 26            Proceeds from sale of equity securities
# 27  Investments in unconsolidated affiliates, net ...    15000000.0
# 28                 Termination of interest rate swaps
# 29                                              Other     4000000.0
# 30                 Net Cash from Investing Activities -1190000000.0
# 31                              Financing activities:
# 32                     Proceeds from issuance of debt  5242000000.0
# 33                     Payment of debt issuance costs   -50000000.0
# 34                                  Repayment of debt -2883000000.0
# 35            Proceeds from revolving credit facility  1921000000.0
# 36             Repayment of revolving credit facility -1767000000.0
# 37    Principal payments on capital lease obligations    -2000000.0
# 38                Payment of contingent consideration    -4000000.0
# 39  Stock issued under employee stock purchase and...    91000000.0
# 40                         Repurchase of common stock -2620000000.0
# 41  Excess income tax benefits from stock-based aw...
# 42                 Net Cash from Financing Activities   -72000000.0
# 43  Effect of foreign currency exchange rate chang...    53000000.0
# 44                                 Net Change in Cash  -239000000.0
# 45                          Cash and Cash Equivalents
# 46                          Cash and Cash Equivalents
#
#       2016-12-31    2015-12-31  level  abstract  dimension
# 0                                   1     False      False
# 1    130000000.0   388000000.0      2     False      False
# 2                                   2     False      False
# 3   -289000000.0  -128000000.0      3     False      False
# 4     30000000.0     9000000.0      3     False      False
# 5      3000000.0     8000000.0      3     False      False
# 6     80000000.0    38000000.0      3     False      False
# 7    -28000000.0    -2000000.0      3     False      False
# 8     -1000000.0    -1000000.0      3     False      False
# 9      8000000.0    -8000000.0      3     False      False
# 10   -13000000.0     1000000.0      3     False      False
# 11   135000000.0    18000000.0      3     False      False
# 12   -41000000.0   -39000000.0      3     False      False
# 13                                  2     False      False
# 14   -62000000.0  -246000000.0      3     False      False
# 15    -8000000.0    15000000.0      3     False      False
# 16   160000000.0   104000000.0      3     False      False
# 17    52000000.0    54000000.0      3     False      False
# 18    70000000.0     5000000.0      3     False      False
# 19   860000000.0   476000000.0      2     False      False
# 20                                  1     False      False
# 21  -164000000.0   -78000000.0      2     False      False
# 22  1887000000.0    32000000.0      2     False      False
# 23                                  2     False      False
# 24   -40000000.0                    2     False      False
# 25    21000000.0                    2     False      False
# 26    41000000.0                    2     False      False
# 27   -17000000.0   -12000000.0      2     False      False
# 28                 -11000000.0      2     False      False
# 29     3000000.0     2000000.0      2     False      False
# 30  1731000000.0   -67000000.0      2     False      False
# 31                                  1     False      False
# 32   466000000.0  2249000000.0      2     False      False
# 33    -7000000.0   -22000000.0      2     False      False
# 34 -1949000000.0 -2057000000.0      2     False      False
# 35   172000000.0                    2     False      False
# 36                                  2     False      False
# 37    -2000000.0    -4000000.0      2     False      False
# 38    -5000000.0    -3000000.0      2     False      False
# 39    97000000.0    64000000.0      2     False      False
# 40 -1097000000.0  -515000000.0      2     False      False
# 41    41000000.0    39000000.0      2     False      False
# 42 -2284000000.0  -249000000.0      2     False      False
# 43   -86000000.0   -50000000.0      1     False      False
# 44   221000000.0   110000000.0      1     False      False
# 45                                  1     False      False
# 46                                  1     False      False
