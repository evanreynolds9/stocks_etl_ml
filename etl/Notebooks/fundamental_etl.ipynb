# %%
# Load packages, utilities, dotenv
import pandas as pd
import os

from etl_utils import extract_query

from dotenv import load_dotenv
load_dotenv()

db_conn_str = f"mysql+pymysql://{os.getenv('DB_USERNAME')}:{os.getenv('DB_PASSWORD')}@{os.getenv('DB_HOST')}:{os.getenv('DB_PORT')}/earnings"

# %%
# Load income statement
income_statement = extract_query(db_conn_str, "SQL\yearly_income_statement.sql")
# Out:
# Connection Successful!
# SQL script at yearly_income_statement.sql executed successfully!

# %%
# No missing data on the income statement
income_statement[income_statement.isna().any(axis = 1)]
# Out:
# Empty DataFrame
# Columns: [date, act_symbol, sales, gross_profit, net_income, diluted_net_eps]
# Index: []

# %%
income_statement["date"] = pd.to_datetime(income_statement["date"])

# %%
income_statement.loc[income_statement.duplicated(subset = ["date","act_symbol"])]
# Out:
# Empty DataFrame
# Columns: [date, act_symbol, sales, gross_profit, net_income, diluted_net_eps]
# Index: []

# %%
# But is the data continuous? We know companies get added at different times, but is their yearly data always available once it has been pulled?
dates = income_statement[['date','act_symbol']].groupby('act_symbol').agg(['min','max', 'size'])

# %%
dates[('date', 'date_diff')] = ((dates[('date', 'max')] - dates[('date', 'min')])/pd.Timedelta(days = 365.25)).round() + 1

# %%
# Do any not match??
dates.loc[dates[('date','size')] != dates[('date', 'date_diff')]]
# Out:
#                  date
#                   min        max size date_diff
# act_symbol
# AACG       2014-12-31 2024-12-31   10      11.0
# ABCM       2020-06-30 2022-12-31    5       4.0
# ABCO       2012-12-31 2016-12-31    4       5.0
# ABIO       2012-12-31 2023-12-31   11      12.0
# ABVC       2018-12-31 2024-12-31    6       7.0
# ...               ...        ...  ...       ...
# YTRA       2016-03-31 2024-03-31    8       9.0
# YVR        2014-02-28 2021-11-30   11       9.0
# ZIVO       2018-12-31 2021-12-31    3       4.0
# ZN         2013-12-31 2018-12-31    5       6.0
# ZWS        2017-12-31 2024-12-31    7       8.0
#
# [722 rows x 4 columns]

# %%
income_statement.dtypes
# Out:
# date               datetime64[ns]
# act_symbol                 object
# sales                     float64
# gross_profit              float64
# net_income                float64
# diluted_net_eps           float64
# month_end          datetime64[ns]
# dtype: object

# %%
income_statement['month_end'] = income_statement['date'] + pd.offsets.MonthEnd(0)

# %%
income_statement[income_statement['date'] != income_statement['month_end']]
# Out:
# Empty DataFrame
# Columns: [date, act_symbol, sales, gross_profit, net_income, diluted_net_eps, month_end]
# Index: []

# %%
# Balance sheet components
balance_sheet_components = ["assets", "equity", "liabilities"]
bs_dfs = []

for component in balance_sheet_components:
    query_path = f"SQL\yearly_balance_sheet_{component}.sql"

    res =  extract_query(db_conn_str, query_path)

    bs_dfs.append(res)
# Out:
# Connection Successful!
# SQL script at yearly_balance_sheet_assets.sql executed successfully!
# Connection Successful!
# SQL script at yearly_balance_sheet_equity.sql executed successfully!
# Connection Successful!
# SQL script at yearly_balance_sheet_liabilities.sql executed successfully!

# %%
# Merge all dataframes
df = income_statement.copy()

for df_i in bs_dfs:
    cur_rows = len(df)

    df = df.merge(df_i, how = "left", on = ["date", "act_symbol"])

    if len(df) != cur_rows:
        print("Row number changed indicating duplicates. Ending process.")
        break

# %%
# There are many rows with blanks
df[df.isna().any(axis = 1)]
# Out:
#              date act_symbol        sales  gross_profit   net_income  \
# 22     2015-12-31       AAAP   98000000.0    78000000.0  -19000000.0
# 29     2013-12-31        AAC  116000000.0   116000000.0    1000000.0
# 163    2024-12-31       AARD          0.0           0.0  -21000000.0
# 183    2013-12-31        AAU          0.0           0.0   -6000000.0
# 186    2016-12-31        AAU          0.0           0.0   -3000000.0
# ...           ...        ...          ...           ...          ...
# 62466  2020-12-31       ZLAB   49000000.0    32000000.0 -269000000.0
# 62513  2019-12-31        ZOM          0.0           0.0  -20000000.0
# 62527  2013-12-31       ZSAN    4000000.0     4000000.0   -6000000.0
# 62538  2019-03-31       ZTEK          0.0           0.0   -2000000.0
# 62545  2015-12-31        ZTO  916000000.0   314000000.0  200000000.0
#
#        diluted_net_eps  total_current_assets  total_assets  total_equity  \
# 22               -0.56                   NaN           NaN           NaN
# 29                0.12                   NaN           NaN           NaN
# 163              -5.15                   NaN           NaN           NaN
# 183              -0.10                   NaN           NaN           NaN
# 186              -0.04                   NaN           NaN           NaN
# ...                ...                   ...           ...           ...
# 62466            -3.46                   NaN           NaN           NaN
# 62513            -0.19                   NaN           NaN           NaN
# 62527            -1.10                   NaN           NaN           NaN
# 62538            -0.03                   NaN           NaN           NaN
# 62545             0.32                   NaN           NaN           NaN
#
#        book_value_per_share  current_portion_long_term_debt  \
# 22                      NaN                             NaN
# 29                      NaN                             NaN
# 163                     NaN                             NaN
# 183                     NaN                             NaN
# 186                     NaN                             NaN
# ...                     ...                             ...
# 62466                   NaN                             NaN
# 62513                   NaN                             NaN
# 62527                   NaN                             NaN
# 62538                   NaN                             NaN
# 62545                   NaN                             NaN
#
#        total_current_liabilities  long_term_debt  total_liabilities
# 22                           NaN             NaN                NaN
# 29                           NaN             NaN                NaN
# 163                          NaN             NaN                NaN
# 183                          NaN             NaN                NaN
# 186                          NaN             NaN                NaN
# ...                          ...             ...                ...
# 62466                        NaN             NaN                NaN
# 62513                        NaN             NaN                NaN
# 62527                        NaN             NaN                NaN
# 62538                        NaN             NaN                NaN
# 62545                        NaN             NaN                NaN
#
# [1595 rows x 14 columns]

# %%
df["date"] = pd.to_datetime(df["date"])

# %%
df
# Out:
#              date act_symbol         sales  gross_profit    net_income  \
# 0      2012-10-31          A  6.858000e+09  3.604000e+09  1.153000e+09
# 1      2013-10-31          A  6.782000e+09  3.535000e+09  7.240000e+08
# 2      2014-10-31          A  6.981000e+09  3.593000e+09  5.040000e+08
# 3      2015-10-31          A  4.038000e+09  2.041000e+09  4.010000e+08
# 4      2016-10-31          A  4.202000e+09  2.197000e+09  4.620000e+08
# ...           ...        ...           ...           ...           ...
# 62643  2020-12-31       ZYXI  8.000000e+07  6.300000e+07  9.000000e+06
# 62644  2021-12-31       ZYXI  1.300000e+08  1.030000e+08  1.700000e+07
# 62645  2022-12-31       ZYXI  1.580000e+08  1.260000e+08  1.700000e+07
# 62646  2023-12-31       ZYXI  1.840000e+08  1.460000e+08  1.000000e+07
# 62647  2024-12-31       ZYXI  1.920000e+08  1.530000e+08  3.000000e+06
#
#        diluted_net_eps  total_current_assets  total_assets  total_equity  \
# 0                 3.27          4.629000e+09  1.053600e+10  5.185000e+09
# 1                 2.10          4.983000e+09  1.068600e+10  5.289000e+09
# 2                 1.49          5.500000e+09  1.083100e+10  5.301000e+09
# 3                 1.20          3.686000e+09  7.479000e+09  4.170000e+09
# 4                 1.40          3.635000e+09  7.802000e+09  4.246000e+09
# ...                ...                   ...           ...           ...
# 62643             0.24          6.300000e+07  7.200000e+07  5.700000e+07
# 62644             0.44          8.300000e+07  1.330000e+08  7.400000e+07
# 62645             0.44          7.000000e+07  1.160000e+08  6.600000e+07
# 62646             0.27          8.800000e+07  1.370000e+08  4.600000e+07
# 62647             0.09          7.500000e+07  1.220000e+08  3.600000e+07
#
#        book_value_per_share  current_portion_long_term_debt  \
# 0                     14.88                             0.0
# 1                     15.99                             0.0
# 2                     15.90                             0.0
# 3                     12.58                             0.0
# 4                     13.09                             0.0
# ...                     ...                             ...
# 62643                  1.64                             0.0
# 62644                  1.94                       5000000.0
# 62645                  1.77                       5000000.0
# 62646                  1.36                             0.0
# 62647                  1.12                             0.0
#
#        total_current_liabilities  long_term_debt  total_liabilities
# 0                   1.893000e+09    2.112000e+09       5.351000e+09
# 1                   1.602000e+09    2.699000e+09       5.397000e+09
# 2                   1.702000e+09    2.762000e+09       5.530000e+09
# 3                   9.760000e+08    1.655000e+09       3.309000e+09
# 4                   9.450000e+08    1.912000e+09       3.556000e+09
# ...                          ...             ...                ...
# 62643               1.000000e+07    0.000000e+00       1.500000e+07
# 62644               2.300000e+07    1.100000e+07       5.900000e+07
# 62645               2.100000e+07    5.000000e+06       5.000000e+07
# 62646               1.900000e+07    0.000000e+00       9.100000e+07
# 62647               1.700000e+07    0.000000e+00       8.600000e+07
#
# [62648 rows x 14 columns]
