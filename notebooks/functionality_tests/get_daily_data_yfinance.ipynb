# %%
import yfinance as yf
from pendulum import datetime
from datetime import timedelta

# %%
tickers = yf.Tickers(["GIL.TO","RY.TO"])
tickers.history(start="2025-12-30", end="2025-12-31")
# Out:
# [*********************100%***********************]  2 of 2 completed
# Price           Close             Dividends             High              \
# Ticker         GIL.TO       RY.TO    GIL.TO RY.TO     GIL.TO       RY.TO
# Date
# 2025-12-30  85.900002  233.343857       0.0   0.0  86.419998  234.277235
#
# Price             Low               Open             Stock Splits        \
# Ticker         GIL.TO       RY.TO GIL.TO       RY.TO       GIL.TO RY.TO
# Date
# 2025-12-30  85.720001  233.254495   86.0  233.889984          0.0   0.0
#
# Price       Volume
# Ticker      GIL.TO    RY.TO
# Date
# 2025-12-30  395500  1606300

# %%
run_date = datetime(2026,2,7,2)
start_date = run_date.date()
end_date = start_date + timedelta(days=1)
df = tickers.history(start=start_date,end=end_date)
# Out:
# [*********************100%***********************]  2 of 2 completed

# %%
# Weird... on a weekend this works, does it assume utc?
print(df)
# Out:
# Price           Close             Dividends             High              \
# Ticker         GIL.TO       RY.TO    GIL.TO RY.TO     GIL.TO       RY.TO
# Date
# 2026-02-06  97.300003  232.720001       0.0   0.0  97.690002  233.350006
#
# Price             Low                   Open             Stock Splits        \
# Ticker         GIL.TO       RY.TO     GIL.TO       RY.TO       GIL.TO RY.TO
# Date
# 2026-02-06  93.120003  231.550003  93.199997  232.289993          0.0   0.0
#
# Price       Volume
# Ticker      GIL.TO    RY.TO
# Date
# 2026-02-06  681789  2647762
